# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/search?q=mobiles%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off?page=1"
content=requests.get(url,headers=headers).text

# %%
soup=BeautifulSoup(content,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e84a00.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
for k in soup.find_all("a",class_="_1lKT03",href=True):
    if("www.flipkart.com" in k["href"]):
        nextpage=requests.get(k["href"])

# %%
mobile=soup.find_all("div",class_="_2kHMtA" )

# %%
len(mobile)
# Out:
# 24

# %%
name=[]
prices=[]
ratings=[]
storage=[]
dispsize=[]
camera=[]
batterypower=[]
processor=[]
for i in mobile:
    name.append(i.find("div", class_="_4rR01T").text.strip())
    prices.append(i.find("div" ,class_="_30jeq3 _1_WHN1").text.strip())
    ratings.append(i.find("div",class_="_3LWZlK").text.strip())
    storage.append(i.find_all("li", class_="rgWa7D")[0].text.strip())
    dispsize.append(i.find_all("li", class_="rgWa7D")[1].text.strip())
    camera.append(i.find_all("li",class_="rgWa7D")[2].text.strip())
    batterypower.append(i.find_all("li",class_="rgWa7D")[3].text.strip())
    processor.append(i.find_all("li",class_="rgWa7D")[4].text.strip())
name
prices
ratings
storage
dispsize
camera
batterypower
processor
# Out:
# ['MediaTek Helio G35 Processor',
#  'Mediatek Helio P35 Processor',
#  '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#  'Qualcomm Snapdragon 778G Processor',
#  'Exynos 850 Processor',
#  'MediaTek G37 Processor',
#  'MediaTek G37 Processor',
#  'Qualcomm Snapdragon 778G Processor',
#  'Exynos 850 Processor',
#  'MediaTek G37 Processor',
#  'Qualcomm Snapdragon 680 Processor',
#  'Qualcomm Snapdragon 778G Processor',
#  'Mediatek Helio G96 Processor',
#  'MediaTek G35 Processor',
#  'Mediatek Helio G96 Processor',
#  'Qualcomm Snapdragon 778G Processor',
#  'Qualcomm Snapdragon 750G Processor',
#  'MediaTek G37 Processor',
#  'Qualcomm Snapdragon 680 Processor',
#  'Qualcomm Snapdragon 695 5G Processor',
#  '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#  'Mediatek Helio A22 Processor',
#  'Mediatek Helio A22 Processor',
#  'Qualcomm Snapdragon 680 Processor']

# %%
d={"name":name,"prices":prices,"ratings":ratings,"storage":storage,"display_size":dispsize,"camera":camera,"battery_power":batterypower,"processor":processor}
pd.DataFrame(d)
# Out:
#                                            name   prices ratings  \
# 0                 POCO C31 (Shadow Gray, 64 GB)   ₹7,499     4.3
# 1        SAMSUNG Galaxy F04 (Opal Green, 64 GB)   ₹9,499     4.5
# 2            APPLE iPhone 14 (Midnight, 128 GB)  ₹71,999     4.7
# 3         POCO X5 Pro 5G (Horizon Blue, 128 GB)  ₹22,999     4.4
# 4    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  ₹11,999     4.4
# 5     Infinix HOT 20 Play (Aurora Green, 64 GB)   ₹8,199     4.4
# 6   Infinix HOT 20 Play (Fantasy Purple, 64 GB)   ₹8,999     4.4
# 7         POCO X5 Pro 5G (Astral Black, 128 GB)  ₹22,999     4.4
# 8    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  ₹11,999     4.4
# 9     Infinix HOT 20 Play (Racing Black, 64 GB)   ₹8,199     4.4
# 10            REDMI 10 (Caribbean Green, 64 GB)   ₹9,999     4.3
# 11        POCO X5 Pro 5G (Horizon Blue, 256 GB)  ₹24,999     4.5
# 12              POCO M4 Pro (Cool Blue, 128 GB)  ₹13,499     4.3
# ...

# %%
final=pd.DataFrame()
for j in range(1,10):
    url="https://www.flipkart.com/search?q=mobiles%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off?page="+str(j)
    content=requests.get(url,headers=headers).text
    soup=BeautifulSoup(content,"lxml")
    mobile=soup.find_all("div",class_="_2kHMtA" )
    name=[]
    prices=[]
    ratings=[]
    storage=[]
    dispsize=[]
    camera=[]
    batterypower=[]
    processor=[]
    for i in mobile:
        name.append(i.find("div", class_="_4rR01T").text.strip())
        prices.append(i.find("div" ,class_="_30jeq3 _1_WHN1").text.strip())
        ratings.append(i.find("div",class_="_3LWZlK").text.strip())
        storage.append(i.find_all("li", class_="rgWa7D")[0].text.strip())
        dispsize.append(i.find_all("li", class_="rgWa7D")[1].text.strip())
        camera.append(i.find_all("li",class_="rgWa7D")[2].text.strip())
        batterypower.append(i.find_all("li",class_="rgWa7D")[3].text.strip())
        processor.append(i.find_all("li",class_="rgWa7D")[4].text.strip())
    p={"name":name,"prices":prices,"ratings":ratings,"storage":storage,"display_size":dispsize,"camera":camera,"battery_power":batterypower,"processor":processor}
    df=pd.DataFrame(p)
    #final=final.append(df)
    final=pd.concat((final,df),axis=0)

# %%
final
# Out:
#                                          name   prices ratings  \
# 0      SAMSUNG Galaxy F04 (Opal Green, 64 GB)   ₹9,499     4.5
# 1               POCO C31 (Shadow Gray, 64 GB)   ₹7,499     4.3
# 2          APPLE iPhone 14 (Midnight, 128 GB)  ₹71,999     4.7
# 3       POCO X5 Pro 5G (Horizon Blue, 128 GB)  ₹22,999     4.5
# 4   Infinix HOT 20 Play (Racing Black, 64 GB)   ₹8,199     4.4
# ..                                        ...      ...     ...
# 19            POCO X5 Pro 5G (Yellow, 128 GB)  ₹22,999     4.4
# 20           REDMI 10 (Midnight Black, 64 GB)   ₹9,999     4.3
# 21    MOTOROLA G62 5G (Midnight Gray, 128 GB)  ₹15,999     4.1
# 22       MOTOROLA g52 (Charcoal Grey, 128 GB)  ₹12,999     4.2
# 23        APPLE iPhone 14 (Starlight, 128 GB)  ₹71,999     4.7
#
#                                           storage  \
# 0     4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 1   4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 2                                      128 GB ROM
# ...

# %%
final.shape
# Out:
# (216, 8)

# %%
final.to_csv("/Users/nishiteotia/Desktop/flipkart_mobiles.csv")
